# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\Python\\Projects\\Flipkart Reviews Scrapper'

# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
flipkart_base_url = "https://www.flipkart.com/search?q="

# %%
search_string = "iphone+11"

# %%
flipkart_url = flipkart_base_url + search_string

# %%
flipkart_page = requests.get(flipkart_url).text

# %%
flipkart_html = bs(flipkart_page, "html.parser")

# %%
print(flipkart_html.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
#   <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
#   <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e0eee8.css" rel="stylesheet"/>
#   <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" rel="preload"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
#    <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#    <meta content="website" property="og:type"/>
# ...

# %%
paragraphs = flipkart_html.find_all('p')

# %%
len(paragraphs)
# Out:
# 38

# %%
products = flipkart_html.findAll("div", {"class": "_2pi5LC col-12-12"})

# %%
len(products)
# Out:
# 30

# %%
product_link = products[3].div.div.div.a['href']

# %%
product_page_link = "https://www.flipkart.com" + product_link

# %%
product_page_link
# Out:
# 'https://www.flipkart.com/apple-iphone-11-green-64-gb-includes-earpods-power-adapter/p/itmfdb5266c6e904?pid=MOBFKCTSKZQCYCWE&lid=LSTMOBFKCTSKZQCYCWEMDZQMV&marketplace=FLIPKART&srno=s_1_2&otracker=search&fm=organic&iid=ab45d30d-258a-4469-b0ac-03c67f448087.MOBFKCTSKZQCYCWE.SEARCH&ssid=o8pifhzhmo0000001607436805722&qH=f6cdfdaa9f3c23f3'

# %%
product_page = requests.get(product_page_link)

# %%
product_page.status_code
# Out:
# 200

# %%
product_html = bs(product_page.text, "html.parser")

# %%
print(product_html.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
#   <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
#   <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e0eee8.css" rel="stylesheet"/>
#   <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" rel="preload"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
#    <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#    <meta content="website" property="og:type"/>
# ...

# %%
review_boxes = product_html.findAll('div', {'class': '_16PBlm'})

# %%
len(review_boxes)
# Out:
# 11

# %%
# Rating
review_boxes[1].div.div.div.div.text
# Out:
# '5'

# %%
# Comment Heading
review_boxes[1].div.div.div.p.text
# Out:
# 'Great product'

# %%
comment_tag = review_boxes[1].div.div.find_all('div', {'class': 't-ZTKy'})

# %%
# Comment 
comment_tag[0].div.div.text
# Out:
# 'Amazing Powerful and Durable Gadget.I’m am very happy with the camera picture quality, Amazing face id unlocked in dark room, Strong battery with perfect screen size as you can carry easily in pocket. This is my third iPhone. I shifted from android Samsung Note series to iPhone because of the strong build quality and peace of mind for next 3-4 years.Don’t think to much just go for it and I suggest you to go for minimum 128gb variant or more 256gb. I’ve attached my puppy pics and no fi...'

# %%
# Name 
review_boxes[1].find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
# Out:
# 'Rahul Verma'

# %%
# Scrapping all the reviews at once and listing them 
review = []

for review_box in review_boxes:
    # Name 
    try: 
        customer_name = review_box.find_all('p', {'class': '_3LYOAd _3sxSiS'})[0].text
    except:
        customer_name = "No Name"
        
    # Rating:
    try:
        customer_rating = review_box.div.div.div.div.text
    except:
        customer_rating = 0
    
    # Review Heading
    try:
        review_heading = review_box.div.div.div.p.text
    except:
        review_heading = 'No Heading'
        
    # Review Message
    try:
        comment_tag = review_box.div.div.find_all('div', {'class': 'qwjRop'})
        review_message = comment_tag[0].div.div.text
    except:
        review_message = "No Review"
        
    reviewDict = {'Name': customer_name, "Rating": customer_rating, "Review Heading": review_heading, 'Review': review_message}
    review.append(reviewDict)

# %%
for i in review:
    print(i)
    print('\n')
# Out:
# {'Name': 'Flipkart Customer', 'Rating': '5', 'Review Heading': 'Perfect product!', 'Review': 'Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .'}
#
#
# {'Name': 'Rahul Verma', 'Rating': '5', 'Review Heading': 'Great product', 'Review': 'Amazing Powerful and Durable Gadget.I’m am very happy with the camera picture quality, Amazing face id unlocked in dark room, Strong battery with perfect screen size as you can carry easily in pocket. This is my third iPhone. I shifted from android Samsung Note series to iPhone because of the strong build quality and peace of mind for next 3-4 years.Don’t think to much just go for it and I suggest you to go for minimum 128gb variant or more 256gb. I’ve attached my puppy pics and no fi...'}
#
#
# ...

# %%
len(products)
# Out:
# 31

# %%
temp = products[3].div.div.div.a['href']
temp
# Out:
# '/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&srno=s_1_1&otracker=search&fm=organic&iid=c417cf3b-0fd7-41f0-90b2-7b7510f3d4a0.MOBFKCTSVZAXUHGR.SEARCH&ssid=25ho178aio0000001604486073124&qH=f6cdfdaa9f3c23f3'

# %%
import re

# %%
word = 'apple-iphone-11'
re.search(word, temp)
# Out:
# <re.Match object; span=(1, 16), match='apple-iphone-11'>

# %%
products= products[4:10]

# %%
links = []

for x in products:
    link = x.div.div.div.a['href']
    links.append(link)

# %%
len(links)
# Out:
# 6

# %%
for link in links:
    print(link)
    print('/n')
# Out:
# /apple-iphone-11-white-64-gb-includes-earpods-power-adapter/p/itm2644c3764fc54?pid=MOBFKCTSHAWGGFHM&lid=LSTMOBFKCTSHAWGGFHMCPQSMX&marketplace=FLIPKART&srno=s_1_2&otracker=search&fm=organic&iid=c417cf3b-0fd7-41f0-90b2-7b7510f3d4a0.MOBFKCTSHAWGGFHM.SEARCH&ssid=25ho178aio0000001604486073124&qH=f6cdfdaa9f3c23f3
# /n
# /apple-iphone-11-purple-64-gb-includes-earpods-power-adapter/p/itm0bc87f7f6d418?pid=MOBFKCTSBUSRZTQC&lid=LSTMOBFKCTSBUSRZTQCUVCBLN&marketplace=FLIPKART&srno=s_1_3&otracker=search&fm=organic&iid=c417cf3b-0fd7-41f0-90b2-7b7510f3d4a0.MOBFKCTSBUSRZTQC.SEARCH&ssid=25ho178aio0000001604486073124&qH=f6cdfdaa9f3c23f3
# /n
# /apple-iphone-11-red-64-gb-includes-earpods-power-adapter/p/itmc3e231769bc6f?pid=MOBFKCTSMSYH9YY8&lid=LSTMOBFKCTSMSYH9YY8TPE8O9&marketplace=FLIPKART&srno=s_1_4&otracker=search&fm=organic&iid=c417cf3b-0fd7-41f0-90b2-7b7510f3d4a0.MOBFKCTSMSYH9YY8.SEARCH&ssid=25ho178aio0000001604486073124&qH=f6cdfdaa9f3c23f3
# /n
# ...

# %%
base_url = "https://www.flipkart.com"
product_reviews = []

for link in links:
    product_link = base_url + link
    product_page = requests.get(product_link)
    if (product_page.status_code == 200):
        product_html = bs(product_page.text, "html.parser")
        review_boxes = product_html.findAll('div', {'class': '_3nrCtb'})
        
        # adding reviews in dictionary
        for review_box in review_boxes:
            # Name 
            try: 
                customer_name = review_box.find_all('p', {'class': '_3LYOAd _3sxSiS'})[0].text
            except:
                customer_name = "No Name"
            # Rating:
            try:
                customer_rating = review_box.div.div.div.div.text
            except:
                customer_rating = 0
            # Review Heading
            try:
                review_heading = review_box.div.div.div.p.text
            except:
                review_heading = 'No Heading'
            # Review Message
            try:
                comment_tag = review_box.div.div.find_all('div', {'class': 'qwjRop'})
                review_message = comment_tag[0].div.div.text
            except:
                review_message = "No Review"

            reviewDict = {'Name': customer_name, 
                          "Rating": customer_rating, 
                          "Review Heading": review_heading, 
                          'Review': review_message}
            product_reviews.append(reviewDict)

# %%
for i in product_reviews:
    print(i)
    print('\n')
# Out:
# {'Name': 'Flipkart Customer', 'Rating': '5', 'Review Heading': 'Perfect product!', 'Review': 'Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .'}
#
#
# {'Name': 'Rahul Verma', 'Rating': '5', 'Review Heading': 'Great product', 'Review': 'Amazing Powerful and Durable Gadget.I’m am very happy with the camera picture quality, Amazing face id unlocked in dark room, Strong battery with perfect screen size as you can carry easily in pocket. This is my third iPhone. I shifted from android Samsung Note series to iPhone because of the strong build quality and peace of mind for next 3-4 years.Don’t think to much just go for it and I suggest you to go for minimum 128gb variant or more 256gb. I’ve attached my puppy pics and no fi...'}
#
#
# ...
